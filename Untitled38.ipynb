# %%
## Import Package
from selenium import webdriver
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from bs4 import NavigableString, Tag

# %%
import os
os.getcwd()
os.chdir("D:/python/Crawling")
os.getcwd()

## Enabled Chrome function 打開模擬瀏覽器
chrome_browser = webdriver.Chrome()
## go to the website
chrome_browser.get("https://www.cathaylife.com.tw/cathaylife/services/info/rate-index/interest")
## Close down the website
# chrome_browser.close()

# %%
page = chrome_browser.page_source
page_soup = BeautifulSoup(page,'html.parser')
print(page_soup)
# Out:
# <html class="no-js iefalse laptop-ver" lang="zh-Hant"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="index,follow" name="robots"/>
# <meta content="zh-TW" http-equiv="content-language"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=1024" name="viewport"/>
# <title id="HtmlTitle">宣告利率｜商品利率公告｜國泰人壽</title>
# <meta content="" id="HtmlMetaDescription" name="description"/>
# <meta content="" id="HtmlMetaKeywords" name="keywords"/>
# <meta content="國泰人壽" name="國泰人壽"/>
# <meta content="國泰人壽" name="author"/>
# <meta content="company" property="og:type"/>
# <meta content="資訊_宣告利率" id="HtmlTag1"/>
# <meta id="HtmlTag2"/>
# <meta id="HtmlTag3"/>
# <meta content="宣告利率｜商品利率公告｜國泰人壽" id="HtmlMetaOGTitle" property="og:title"/>
# <meta content="https://www.cathaylife.com.tw/cathaylife/web/img/common/logo.gif" id="HtmlMetaOGImage" property="og:image"/>
# <meta content="" id="HtmlMetaOGDescription" property="og:description"/>
# <meta content="0" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <link href="/cathaylife/web/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/cathaylife/web/img/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/cathaylife/web/img/favicon.ico" rel="bookmark" type="image/x-icon"/>
# <link href="/cathaylife/web/css/common.css?v=22" rel="stylesheet"/>
# <link href="/cathaylife/web/css/vendor.css?v=22" rel="stylesheet"/>
# <link href="/cathaylife/-/media/life-insurance/files/scripts/privacy/privacy-min-css?v=22" rel="stylesheet"/>
# <!-- 新天地用CSS / 開始 -->
# <link href="/cathaylife/web/headerfooter/css/headerfooter.css?v=22" rel="stylesheet"/>
# <!-- 新天地用CSS / 結束 -->
# <style>
# .header nav li {
#     float: none;
# }
# </style>
# <!-- Google Tag Manager -->
# <iframe src="https://img.scupio.com/html/ls.html?mid=0" style="display: none; position: absolute; visibility: hidden;"></iframe><script async="" src="https://tags.crwdcntrl.net/lt/c/16163/sync.min.js"></script><script async="" src="https://cdn.id5-sync.com/api/1.0/id5-api.js"></script><script async="" src="https://connect.facebook.net/signals/config/641816176531849?v=2.9.45&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/242257463733598?v=2.9.45&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/221416555458154?v=2.9.45&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="https://img.scupio.com/js/pixel.js"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="//jscdn.appier.net/aa.js?id=cathaylife.com.tw"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-BQ2KWMRPRE&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-KCP5QFP"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WLKJB7"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WLKJB7');</script>
# <!-- End Google Tag Manager -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KCP5QFP');</script>
# <!-- End Google Tag Manager -->
# <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/772873973/?random=1631627763484&amp;cv=9&amp;fst=1631627763484&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg9d0&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.cathaylife.com.tw%2Fcathaylife%2Fservices%2Finfo%2Frate-index%2Finterest&amp;tiba=%E5%AE%A3%E5%91%8A%E5%88%A9%E7%8E%87%EF%BD%9C%E5%95%86%E5%93%81%E5%88%A9%E7%8E%87%E5%85%AC%E5%91%8A%EF%BD%9C%E5%9C%8B%E6%B3%B0%E4%BA%BA%E5%A3%BD&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/629576939/?random=1631627763493&amp;cv=9&amp;fst=1631627763493&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg9d0&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.cathaylife.com.tw%2Fcathaylife%2Fservices%2Finfo%2Frate-index%2Finterest&amp;tiba=%E5%AE%A3%E5%91%8A%E5%88%A9%E7%8E%87%EF%BD%9C%E5%95%86%E5%93%81%E5%88%A9%E7%8E%87%E5%85%AC%E5%91%8A%EF%BD%9C%E5%9C%8B%E6%B3%B0%E4%BA%BA%E5%A3%BD&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/620970804/?random=1631627763497&amp;cv=9&amp;fst=1631627763497&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg9d0&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.cathaylife.com.tw%2Fcathaylife%2Fservices%2Finfo%2Frate-index%2Finterest&amp;tiba=%E5%AE%A3%E5%91%8A%E5%88%A9%E7%8E%87%EF%BD%9C%E5%95%86%E5%93%81%E5%88%A9%E7%8E%87%E5%85%AC%E5%91%8A%EF%BD%9C%E5%9C%8B%E6%B3%B0%E4%BA%BA%E5%A3%BD&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><meta content="" http-equiv="origin-trial"/><script id="cubcsacsaId" src="https://adc.cathaybk.com.tw/JavascriptInsert.js" type="text/javascript"></script><link href="https://www.cathaylife.com.tw/website/eService/css/smart_style.css" rel="stylesheet"/><style type="text/css">.fancybox-margin{margin-right:17px;}</style></head>
# <body style="padding-top: 0px;">
# <form action="/cathaylife/services/info/rate-index/interest" id="mainform" method="post">
# <div class="aspNetHidden">
# <input id="__EVENTTARGET" name="__EVENTTARGET" type="hidden" value=""/>
# <input id="__EVENTARGUMENT" name="__EVENTARGUMENT" type="hidden" value=""/>
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <script type="text/javascript">
# //<![CDATA[
# var theForm = document.forms['mainform'];
# if (!theForm) {
#     theForm = document.mainform;
# }
# function __doPostBack(eventTarget, eventArgument) {
#     if (!theForm.onsubmit || (theForm.onsubmit() != false)) {
#         theForm.__EVENTTARGET.value = eventTarget;
#         theForm.__EVENTARGUMENT.value = eventArgument;
#         theForm.submit();
#     }
# }
# //]]>
# </script>
# <script src="/cathaylife/web/js/ajax/MicrosoftAjax.js" type="text/javascript"></script>
# <script src="/cathaylife/web/js/ajax/MicrosoftAjaxWebForms.js" type="text/javascript"></script>
# <script src="/cathaylife/web/js/ajax/WebForms.js" type="text/javascript"></script>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="BD6196D2"/>
# </div>
# <script type="text/javascript">
# //<![CDATA[
# Sys.WebForms.PageRequestManager._initialize('layout_0$ctl00', 'mainform', [], [], [], 90, '');
# //]]>
# </script>
# <header class="cli-wrap cli-header">
# <nav class="navbar navbar-expand-lg">
# <div class="navbar-upper-nav navbar-first-menu">
# <div class="container">
# <a class="navbar-brand" href="/cathaylife/" id="layout_0_header_menu_0_Logo_Link" style="background-image:url(/cathaylife/-/media/762fcafe04e64c1da400a8b507c832b8?v=1)">國泰人壽</a>
# <ul class="navbar-nav nav-unit-menu">
# <li class="nav-item active" id="layout_0_header_menu_0_RepSiteMenu_liMenuTypes_0">
# <a class="nav-link" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/" id="lnk_awd-megamenu_SiteMenuLink">
#                                     個人客戶
#                                 </a>
# </li>
# <li class="nav-item" id="layout_0_header_menu_0_RepSiteMenu_liMenuTypes_1">
# <a class="nav-link" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/campaign/B2B2C_Groupins" id="lnk_awd-megamenu_SiteMenuLink" rel="noopener noreferrer" target="_blank">
#                                     企業客戶
#                                 </a>
# </li>
# <li class="nav-item" id="layout_0_header_menu_0_RepSiteMenu_liMenuTypes_2">
# <a class="nav-link" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/webStatics/Employee/employee/index.html" id="lnk_awd-megamenu_SiteMenuLink" rel="noopener noreferrer" target="_blank">
#                                     國泰員工
#                                 </a>
# </li>
# <li class="nav-item" id="layout_0_header_menu_0_RepSiteMenu_liMenuTypes_3">
# <a class="nav-link" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/enterprise/info/student" id="lnk_awd-megamenu_SiteMenuLink" rel="noopener noreferrer" target="_blank">
#                                     學生團體
#                                 </a>
# </li>
# <li class="nav-item" id="layout_0_header_menu_0_RepSiteMenu_liMenuTypes_4">
# <a class="nav-link" enclosing-tag="awd-megamenu" href="/cathaylife/recruiting" id="lnk_awd-megamenu_SiteMenuLink">
#                                     人才招募
#                                 </a>
# </li>
# <li class="nav-item">
# <a class="nav-link translateLanguage" href="https://www.cathaylife.com.tw/cathaylife/webStatics/official/english/index.html" id="lnk_LanguageLink" rel="noopener noreferrer" target="_blank">
#                                     EN
#                                 </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="navbar-mega-menu section-nav" id="navbarHeader">
# <div class="container">
# <ul class="navbar-nav">
# <li class="nav-item dropdown mega-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" enclosing-tag="awd-megamenu">
# <img class="img-icon" data-hover="/cathaylife/-/media/35b26fce18d04f0594923d724489ed0d?v=1" data-img="/cathaylife/-/media/65528523522d403282ad5c57fd767f97?v=1" data-sticky="/cathaylife/-/media/14157f9aacbb434e900be6ba84f0d34c?v=1" id="layout_0_header_menu_0_RepLV01Menu_LV01Menu_Image_0" src="/cathaylife/-/media/65528523522d403282ad5c57fd767f97?v=1" style="height:25px;width:25px;"/>
# <span>商品資訊</span>
# </a>
# <div aria-labelledby="menu-1" class="dropdown-menu mega-dropdown-menu" id="layout_0_header_menu_0_RepLV01Menu_Div_MenuLv1__Child_0">
# <div class="container">
# <ul class="mega-dropdown-menu-inner">
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/products/health-surgery" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             個人保險
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/health-surgery" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             健康醫療險
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/accident" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             意外傷害險
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/life-caring" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             壽險
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/savings-refund" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             還本/年金型保險
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/investment-va" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             投資型保險
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/travel-insurance-index" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             旅行平安險
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/selling" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             限定通路商品
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/selling/selling-bank" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             銀行通路商品
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/selling/selling-tele" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             電話行銷商品
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://online.cathaylife.com.tw/OIWeb/servlet/HttpDispatcher/OIA0_0100/prompt" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             網路投保商品
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/group" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             其他特色商品
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/group" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             團體保險
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/simple-insurance" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             微型保險
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/spillover" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             外溢保險
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/oiu" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             國際保險業務 OIU
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/mortgage-index/mortgage-products" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             房貸商品
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/co-marketing-index" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             共同行銷與代銷專區
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/active-your-insurance" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             保單活化專區
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/public-servants" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             公教人員專區
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/public-servants" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             投保資格及規定
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/products/insurance/protection/public-servants#first-tab-02" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             專屬商品及公教專刊網
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/products/insurance/protection/public-servants#first-tab-03" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             理賠專區
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/products/insurance/protection/public-servants#first-tab-04" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             預約專人服務
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/products/insurance/protection/public-servants#first-tab-05" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             常見Q&amp;A
#                                                                         </a>
# </li>
# </ul>
# </li>
# </ul>
# <div class="c-fastEntry">
# <a class="c-fastEntryIcon" enclosing-tag="awd-megamenu" href="https://online.cathaylife.com.tw/OIWeb/servlet/HttpDispatcher/OIB0_1000/prompt" id="lnk_awd-megamenu_LV01QuickLinkLink" rel="noopener noreferrer" target="_blank">
# <img class="img-icon" data-hover="" data-img="/cathaylife/-/media/cfc50d0db6ee4437b7ae536492b55574?v=1" id="layout_0_header_menu_0_RepLV01Menu_RepLV01QuickLinks_0_LV01QuickLink_Image_0" src="/cathaylife/-/media/cfc50d0db6ee4437b7ae536492b55574?v=1"/>
# <p>旅平險試算</p>
# </a>
# <a class="c-fastEntryIcon" enclosing-tag="awd-megamenu" href="/cathaylife/products/insurance/mortgage-index/mortgage-calc" id="lnk_awd-megamenu_LV01QuickLinkLink" rel="noopener noreferrer">
# <img class="img-icon" data-hover="" data-img="/cathaylife/-/media/3ddb6319fff048c6b62a85b77f3ea54c?v=1" id="layout_0_header_menu_0_RepLV01Menu_RepLV01QuickLinks_0_LV01QuickLink_Image_1" src="/cathaylife/-/media/3ddb6319fff048c6b62a85b77f3ea54c?v=1"/>
# <p>房貸試算</p>
# </a>
# <a class="c-fastEntryIcon" enclosing-tag="awd-megamenu" href="https://campaigns.cathaylife.com.tw/OAWeb/html/OA/C8/index.html?utm_source=officialpc&amp;utm_medium=menu&amp;cele_placement=officialpc&amp;cele_type=menu" id="lnk_awd-megamenu_LV01QuickLinkLink_預約顧問諮詢" rel="noopener noreferrer" target="_blank" title="預約顧問諮詢">
# <img class="img-icon" data-hover="" data-img="/cathaylife/-/media/79b305522fe9489fa00b1958c1514873?v=1" id="layout_0_header_menu_0_RepLV01Menu_RepLV01QuickLinks_0_LV01QuickLink_Image_2" src="/cathaylife/-/media/79b305522fe9489fa00b1958c1514873?v=1"/>
# <p>預約顧問諮詢</p>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown mega-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/" id="lnk_awd-megamenu_LV01MenuLink">
# <img class="img-icon" data-hover="/cathaylife/-/media/b8fa9adbb15544fda5d8b46b4e37c787?v=1" data-img="/cathaylife/-/media/97d90abe56784a78b6ecfd363347c93c?v=1" data-sticky="/cathaylife/-/media/4d99033b4eca4f39b725fe6a0cdfa9c7?v=1" id="layout_0_header_menu_0_RepLV01Menu_LV01Menu_Image_1" src="/cathaylife/-/media/97d90abe56784a78b6ecfd363347c93c?v=1" style="height:25px;width:25px;"/>
# <span>投資標的專區</span>
# </a>
# <div aria-labelledby="menu-1" class="dropdown-menu mega-dropdown-menu" id="layout_0_header_menu_0_RepLV01Menu_Div_MenuLv1__Child_1">
# <div class="container">
# <ul class="mega-dropdown-menu-inner">
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             業務通路商品
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$W$HTML$SELECT]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             投資標的總覽
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$W$HTML$TGINTEREST]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             標的配息/撥回資訊
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$W$WLIFE$ADDPORTFOLIO]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             基金組合模擬
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$W$WS$SCATTERLIFE]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             基金風險報酬象限
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$W$WB$WB03A]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             國內外基金綜合比較
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=HTTPS:$$WWW]CATHAYLIFE]COM]TW$CATHAYLIFE$IFRAME$STRUCTURED-NOTE$BASIC" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             結構債/公司債
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             銀行通路商品
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=HTTPS:$$ILP]CATHAYLIFE]COM]TW$W$HTML$SELECT]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             投資標的總覽
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=HTTPS:$$ILP]CATHAYLIFE]COM]TW$W$HTML$TGINTEREST]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             標的配息/撥回資訊
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=HTTPS:$$ILP]CATHAYLIFE]COM]TW$W$WLIFE$ADDPORTFOLIO]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             基金組合模擬
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=HTTPS:$$ILP]CATHAYLIFE]COM]TW$W$WS$SCATTERLIFE]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             基金風險報酬象限
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=HTTPS:$$ILP]CATHAYLIFE]COM]TW$W$WB$WB03A]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             國內外基金綜合比較
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             財經資訊
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$ETFWEB$HTML$ETKMDJNEWS]DJHTM?|TYPE}1!PAGE}1" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             財經新聞
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$W$WJ$IQUOTE]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             金融情報
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=HTTPS:$$WWW]CATHAYLIFE]COM]TW$CATHAYLIFE$IFRAME$REPORT" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             基金研究報告
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$ETFWEB$HTML$ET^NN]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             匯率行情
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$W$WI$EXCHANGE]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             交叉匯率查詢
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://fund.cathaylife.com.tw/content.html?sUrl=$^$^C$INVPRESSRWD]DJHTM" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             全球投資快報
#                                                                         </a>
# </li>
# </ul>
# </li>
# </ul>
# <div class="c-fastEntry">
# <a class="c-fastEntryIcon" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/oc/OCWeb/html/OC/Login/Login.jsp" id="lnk_awd-megamenu_LV01QuickLinkLink" rel="noopener noreferrer" target="_blank">
# <img class="img-icon" data-hover="" data-img="/cathaylife/-/media/465ca919d59d4498ae5816a7be992f57?v=1" id="layout_0_header_menu_0_RepLV01Menu_RepLV01QuickLinks_1_LV01QuickLink_Image_0" src="/cathaylife/-/media/465ca919d59d4498ae5816a7be992f57?v=1"/>
# <p>投資標的轉換</p>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown mega-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/insurance-premium" id="lnk_awd-megamenu_LV01MenuLink">
# <img class="img-icon" data-hover="/cathaylife/-/media/b38fa0e26e784fdba700dfcc125899b7?v=1" data-img="/cathaylife/-/media/47a7c0378a8f4469896e0a37c4c965b4?v=1" data-sticky="/cathaylife/-/media/d4d890541d6f43ce842542e150a70e23?v=1" id="layout_0_header_menu_0_RepLV01Menu_LV01Menu_Image_2" src="/cathaylife/-/media/47a7c0378a8f4469896e0a37c4c965b4?v=1" style="height:25px;width:25px;"/>
# <span>保單服務</span>
# </a>
# <div aria-labelledby="menu-1" class="dropdown-menu mega-dropdown-menu" id="layout_0_header_menu_0_RepLV01Menu_Div_MenuLv1__Child_2">
# <div class="container">
# <ul class="mega-dropdown-menu-inner">
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/insurance-premium" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             保費服務
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/insurance-premium" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             繳費管道介紹
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/insurance-changing" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             保單變更
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-changing#first-tab-01" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             基本資料變更
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-changing#first-tab-02" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             保單內容變更
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-changing#first-tab-04" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             申請書下載
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/insurance-loan" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             保單借款
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-loan#first-tab-01" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             ATM保單借款
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-loan#first-tab-02" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             服務人員代送
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-loan#first-tab-03" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             臨櫃辦理
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-loan#first-tab-04" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             線上保單借款
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/insurance-paying" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             保險金給付
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-paying#first-tab-01" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             指定匯撥帳號申請
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-paying#first-tab-02" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             領取保險金
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/insurance-paying#first-tab-03" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             申請書下載
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/claim" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             理賠專區
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/claim/claim" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             理賠申請方式
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/claim/claim-docs" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             應備文件查詢/下載
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/claim/claim-offset" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             理賠金抵繳住院費
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/claim/claim-oversea" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             海外理賠服務
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/apply-certification" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             申辦/補發證明文件
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/apply-certification" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             年度繳費證明
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/apply-certification#first-tab-02" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             英文投保證明
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/apply-certification#first-tab-03" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             補發保險單
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/apply-certification#first-tab-04" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             契約狀況一覽表
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://www.cathaylife.com.tw/cathaylife/services/info/apply-certification#first-tab-05" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             補發電子單據
#                                                                         </a>
# </li>
# </ul>
# </li>
# </ul>
# <div class="c-fastEntry">
# <a class="c-fastEntryIcon" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/cathaylife-app" id="lnk_awd-megamenu_LV01QuickLinkLink_國泰人壽APP下載" rel="noopener noreferrer" title="國泰人壽APP下載">
# <img class="img-icon" data-hover="" data-img="/cathaylife/-/media/541767e99af14dc79e84602370a8f389?v=1" id="layout_0_header_menu_0_RepLV01Menu_RepLV01QuickLinks_2_LV01QuickLink_Image_0" src="/cathaylife/-/media/541767e99af14dc79e84602370a8f389?v=1"/>
# <p>國泰人壽APP下載</p>
# </a>
# <a class="c-fastEntryIcon" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/union-claim-change" id="lnk_awd-megamenu_LV01QuickLinkLink" rel="noopener noreferrer">
# <img class="img-icon" data-hover="" data-img="/cathaylife/-/media/3e756b7de81b4e30922d45acb821cba5?v=1" id="layout_0_header_menu_0_RepLV01Menu_RepLV01QuickLinks_2_LV01QuickLink_Image_1" src="/cathaylife/-/media/3e756b7de81b4e30922d45acb821cba5?v=1"/>
# <p>保全/理賠聯盟鏈</p>
# </a>
# <a class="c-fastEntryIcon" enclosing-tag="awd-megamenu" href="/cathaylife/contact-index/info/location" id="lnk_awd-megamenu_LV01QuickLinkLink" rel="noopener noreferrer">
# <img class="img-icon" data-hover="" data-img="/cathaylife/-/media/8add010b4b6644daa86527b8630f1a34?v=1" id="layout_0_header_menu_0_RepLV01Menu_RepLV01QuickLinks_2_LV01QuickLink_Image_2" src="/cathaylife/-/media/8add010b4b6644daa86527b8630f1a34?v=1"/>
# <p>服務據點</p>
# </a>
# <a class="c-fastEntryIcon" enclosing-tag="awd-megamenu" href="/cathaylife/services/info/rate-index/interest" id="lnk_awd-megamenu_LV01QuickLinkLink" rel="noopener noreferrer">
# <img class="img-icon" data-hover="" data-img="/cathaylife/-/media/313d17b0d4c64f739eff665c6cf57e2f?v=1" id="layout_0_header_menu_0_RepLV01Menu_RepLV01QuickLinks_2_LV01QuickLink_Image_3" src="/cathaylife/-/media/313d17b0d4c64f739eff665c6cf57e2f?v=1"/>
# <p>宣告利率</p>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown mega-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" enclosing-tag="awd-megamenu" href="/cathaylife/add-value/info/benefit" id="lnk_awd-megamenu_LV01MenuLink">
# <img class="img-icon" data-hover="/cathaylife/-/media/200949be6f384f53bbffd25d118fd49e?v=1" data-img="/cathaylife/-/media/cffef66ddccb489b97146147ee0bac71?v=1" data-sticky="/cathaylife/-/media/11d47a037e09433ea41472d6abfca83f?v=1" id="layout_0_header_menu_0_RepLV01Menu_LV01Menu_Image_3" src="/cathaylife/-/media/cffef66ddccb489b97146147ee0bac71?v=1" style="height:25px;width:25px;"/>
# <span>加值服務</span>
# </a>
# <div aria-labelledby="menu-1" class="dropdown-menu mega-dropdown-menu" id="layout_0_header_menu_0_RepLV01Menu_Div_MenuLv1__Child_3">
# <div class="container">
# <ul class="mega-dropdown-menu-inner">
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/add-value/info/benefit" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             保戶好康
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/add-value/info/benefit" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             保戶優惠
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/add-value/info/benefit/member-scholarship" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             客戶子女獎學金
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/add-value/info/benefit/member-oversea" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             海外急難救助
#                                                                         </a>
# </li>
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="https://campaigns.cathaylife.com.tw/OAWeb/servlet/HttpDispatcher/OACB_0100/vipInfoC" id="lnk_awd-megamenu_LV03MenuLink" rel="noopener noreferrer" target="_blank">
#                                                                             免費健康檢查
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="https://campaigns.cathaylife.com.tw/OAWeb/servlet/HttpDispatcher/OACB_0100/Prompt" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             VIP服務專區
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/add-value/info/vip" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             VIP服務專區
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="https://campaigns.cathaylife.com.tw/OAWeb/servlet/HttpDispatcher/OACS/index" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             概念店專區
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# <a class="dropdown-item" enclosing-tag="awd-megamenu" href="/cathaylife/add-value/info/oacs" id="lnk_awd-megamenu_LV03MenuLink">
#                                                                             概念店專區
#                                                                         </a>
# </li>
# </ul>
# </li>
# <li aria-expanded="false" aria-haspopup="true" class="dropdown" data-toggle="dropdown" id="menu-11">
# <a class="dropdown-title dropdown-toggle" enclosing-tag="awd-megamenu" href="/cathaylife/about/info/info-security/certifiable-disease" id="lnk_awd-megamenu_LV02MenuLink">
#                                                             新冠肺炎關懷專區
#                                                         </a>
# <ul aria-labelledby="menu-11" class="">
# <li>
# ...
# <li>宣告利率上限為宣告前中央銀行所公布最近一月之十年期中央政府公債次級市場殖利率，下限為0%之利變年金商品為: 國泰人壽新利率變動型年金保險（甲型、乙型）、國泰人壽新輕鬆理財利率變動型年金保險（甲型、乙型）、國泰人壽超滿意利率變動型年金保險（甲型、乙型）、國泰人壽超輕鬆理財利率變動型年金保險（甲型、乙型）。</li>
# <li>其餘利變年金商品最低宣告不得為負數。</li>
# <li>「特定年度加值利率」適用第一、十保單年度，適用條件等相關規範請參閱保單條款。</li>
# <li>三行庫上月月初（第一營業日）牌告之「二年期定期儲蓄存款」最高固定年利率之平均值與最近一月之十年期中央政府公債次級市場殖利率，如下表。</li>
# <br/>
# <table style="margin-right: 12px;">
# <colgroup>
# <col width="70%"/>
# <col width="30%"/>
# </colgroup>
# <tbody border="1" style="border: 1px solid #bbbbbb; border-image: none;" width="90%">
# <tr style="border: 1.5px solid #bbbbbb; border-image: none;">
# <td style="padding: 5px; background-color: #a8d8b9;">三行庫二年期定期儲存款利率平均值(%)</td>
# <td style="padding: 5px;">0.81%</td>
# </tr>
# <tr style="border: 1.5px solid #bbbbbb; border-image: none;">
# <td style="padding: 5px; background-color: #a8d8b9;">十年期中央政府公債次級市場殖利率(%)</td>
# <td style="padding: 5px;">0.40% </td>
# </tr>
# </tbody>
# </table>
# </ol>
# </div>
# </main>
# </div>
# <section class="c-privacy" id="layout_0_footercontent_0_Msg_Wrap">
# <div class="l-wrap">
# <div class="c-privacy__container">
# <div class="c-privacy__main">
# <ul>
# <li class="msg-content">為提供您最佳個人化且即時的服務，本網站透過使用Cookies記錄與存取您的瀏覽使用訊息。當您使用本網站，即表示您同意Cookies技術支援。（更多資訊請參閱<span style="color: #00b050;"><a href="https://www.cathaylife.com.tw/cathaylife/about/info/info-security/privacy" id="link_1560333218156">隱私權保護政策</a></span>，如需修改Cookie設定請參閱第四點、第九點）</li>
# </ul>
# </div>
# <div class="c-privacy__action">
# <a class="o-btn o-btn--primary" data-id="privacy" href="#" id="privacy">接受</a>
# </div>
# </div>
# </div>
# </section>
# <div class="cli-footer cli-wrap">
# <div class="f-recommandLink">
# <nav class="footer-primary-wrap">
# <div class="container">
# <a class="navbar-brand" href="/cathaylife/" id="lnk_LogoLink">國泰人壽</a>
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="nav-link" enclosing-tag="footer" href="https://www.cathayholdings.com/holdings?_ga=2.85450841.1766570827.1576438411-400139914.1574729221" id="lnk_footer_CompanyLink" rel="noopener noreferrer" target="_blank">
#                                     國泰金控
#                                 </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" enclosing-tag="footer" href="https://www.cathaybk.com.tw/cathaybk/" id="lnk_footer_CompanyLink" rel="noopener noreferrer" target="_blank">
#                                     國泰世華銀行
#                                 </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" enclosing-tag="footer" href="https://www.cathay-ins.com.tw/insurance" id="lnk_footer_CompanyLink" rel="noopener noreferrer" target="_blank">
#                                     國泰產險
#                                 </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" enclosing-tag="footer" href="https://www.cathaysec.com.tw/" id="lnk_footer_CompanyLink" rel="noopener noreferrer" target="_blank">
#                                     國泰綜合證券
#                                 </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" enclosing-tag="footer" href="https://www.cathaysite.com.tw/index.aspx" id="lnk_footer_CompanyLink" rel="noopener noreferrer" target="_blank">
#                                     國泰投信
#                                 </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" enclosing-tag="footer" href="https://www.cathayconsult.com.tw/" id="lnk_footer_CompanyLink" rel="noopener noreferrer" target="_blank">
#                                     國泰投顧
#                                 </a>
# </li>
# </ul>
# <a class="footer-go-top" href="javascript:;" role="page-go-top"></a>
# </div>
# </nav>
# <nav class="footer-secondary-wrap">
# <div class="container">
# <ul class="social-media-links mr-auto">
# <li>
# <a class="fb-link" enclosing-tag="footer" href="https://www.facebook.com/Cathaylife/" id="lnk_footer_SocialLink"> </a>
# </li>
# <li>
# <a class="line-link" enclosing-tag="footer" href="https://line.me/R/ti/p/@cathaylife" id="lnk_footer_SocialLink"> </a>
# </li>
# <li>
# <a class="ytube-link" enclosing-tag="footer" href="https://www.youtube.com/user/cathaylife50?feature=results%2F" id="lnk_footer_SocialLink"> </a>
# </li>
# <li>
# <a enclosing-tag="footer" href="/cathaylife/about/info/info-security/privacy" id="lnk_footer_Link">
#                                     隱私權保護政策
#                                 </a>
# </li>
# <li>
# <a enclosing-tag="footer" href="/cathaylife/about/info/info-security/secret-statement" id="lnk_footer_Link">
#                                     顧客資料保密措施
#                                 </a>
# </li>
# <li>
# <a enclosing-tag="footer" href="/cathaylife/about/info/public-info/company-profile" id="lnk_footer_Link">
#                                     資訊公開
#                                 </a>
# </li>
# <li>
# <a enclosing-tag="footer" href="https://b2b.cathaylife.com.tw/CXBWeb/login?sys=BT" id="lnk_footer_Link_體檢院所平台" rel="noopener noreferrer" target="_blank" title="體檢院所平台">
#                                     體檢院所平台
#                                 </a>
# </li>
# <li>
# <a>
#                             ©國泰人壽股份有限公司
#                         </a>
# </li>
# </ul>
# <ul class="contact-info-group p-0 mt-3">
# <li class="mb-0">
#                                 服務專線：<a href="tel:0800818001" id="layout_0_footercontent_0_RepMobileTel_Tel_Link_0">0800-818-001</a>
# </li>
# </ul>
# <ul class="qa-privacy-group mt-2">
# <li>
# <a enclosing-tag="footer" href="/cathaylife/about/info/info-security/privacy" id="lnk_footer_Link">
#                                     隱私權保護政策
#                                 </a>
# </li>
# <li>
# <a enclosing-tag="footer" href="/cathaylife/about/info/info-security/secret-statement" id="lnk_footer_Link">
#                                     顧客資料保密措施
#                                 </a>
# </li>
# <li>
# <a enclosing-tag="footer" href="/cathaylife/about/info/public-info/company-profile" id="lnk_footer_Link">
#                                     資訊公開
#                                 </a>
# </li>
# <li>
# <a enclosing-tag="footer" href="https://b2b.cathaylife.com.tw/CXBWeb/login?sys=BT" id="lnk_footer_Link_體檢院所平台" rel="noopener noreferrer" target="_blank" title="體檢院所平台">
#                                     體檢院所平台
#                                 </a>
# </li>
# </ul>
# <ul class="qa-privacy-group mt-2 mb-3">
# <li>©國泰人壽股份有限公司</li>
# </ul>
# </div>
# </nav>
# </div>
# </div>
# </form>
# <script src="/cathaylife/web/js/vendor.js?v=22"></script><script id="" src="https://www.cathaylife.com.tw/oc/OCWeb/html/CM/js/CelebrusInsert.js" type="text/javascript"></script><script id="" type="text/javascript">(function(){var d="";try{d=("; "+document.cookie).split("; cubcsapersisted\x3d").pop().split(";").shift().substring(7).split("_")[0]}catch(a){}"undefined"==typeof window.APPIER_RETARGET&&function(a,b,g,e){var f=b.getElementsByTagName("script")[0];b=b.createElement("script");var c="APPIER_RETARGET";a._appierSendQueue=a._appierSendQueue||[];a.appierRetargetJson={id:g,site:e};b.async=!0;b.src="//jscdn.appier.net/aa.js?id\x3d"+e;f.parentNode.insertBefore(b,f);!a[c]&&(a[c]={});!a[c].send&&(a[c].send=function(h){a._appierSendQueue.push(h)})}(window,
# document,"Uj4k","cathaylife.com.tw");window.APPIER_RETARGET.send({t:"pv_track",action_id:"dIpz6r8WxN519A7 ",track_id:"mTgVbk3iwHahR9L",isCountReload:!0,counter:0});window.APPIER_RETARGET.send({t:"pv_track",action_id:"h4AdAEQU7jxvv1t ",track_id:"mTgVbk3iwHahR9L",isCountReload:!1,counter:1});window.APPIER_RETARGET.send({dmp_id:d})})();</script>
# <script id="" src="//jscdn.appier.net/js/rt-ext/track-ext-a.js" type="text/javascript"></script><script id="" type="text/javascript">!function(a,d,e,c,f,g,h,k){if(!a._bw){var b=a._bw=function(){b.callMethods?b.callMethods.apply(b,arguments):b.queue.push(arguments)};b.queue=[];a=d.createElement(e);a.async=!0;a.src=c;c=d.getElementsByTagName(e)[0];c.parentNode.insertBefore(a,c)}}(window,document,"script","https://img.scupio.com/js/pixel.js");(window._bwq=window._bwq||[]).push(["init","1005-13D0A47D0WCE0DR"]);(window._bwq=window._bwq||[]).push(["trackSingle","1005-13D0A47D0WCE0DR","PageView"]);</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","221416555458154");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=221416555458154&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","242257463733598");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=242257463733598&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","641816176531849");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=641816176531849&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script src="https://www.cathaylife.com.tw/website/PFWeb/js/common/CelebrusInsert_p.js" type="text/javascript"></script>
# <script id="" type="text/javascript">window.criteo_q=window.criteo_q||[];var deviceType=/iPad/.test(navigator.userAgent)?"t":/Mobile|iP(hone|od)|Android|BlackBerry|IEMobile|Silk/.test(navigator.userAgent)?"m":"d";window.criteo_q.push({event:"setAccount",account:72378},{event:"setEmail",email:""},{event:"setSiteType",type:deviceType},{event:"viewHome"});</script>
# <div id="criteo-tags-div" style="display: none;"></div>
# <script src="/cathaylife/web/js/cathaylife-vendor.js?v=22"></script>
# <script src="/cathaylife/web/js/custom/tab.js?v=22"></script>
# <script src="/cathaylife/web/js/custom/mutiTabContainer.js?v=22"></script>
# <!--[if lt ie 10]>
# <script type=“text/javascript” src=“/cathaylife/web/js/jquery.placeholder.min.js”?v=22></script>
# <script type=“text/javascript” src=“/cathaylife/web/js/jquery-ie-text-shadow.js”?v=22></script>
# <![endif]-->
# <script src="/cathaylife/-/media/life-insurance/files/scripts/main?v=22"></script>
# <!--script src="/cathaylife/web/js/cookie-msg.js"></script-->
# <script src="/cathaylife/web/js/custom/common.js?v=22"></script>
# <script src="/cathaylife/-/media/life-insurance/files/scripts/privacy/js-cookie/jscookieminmin?v=22"></script>
# <script src="/cathaylife/-/media/life-insurance/files/scripts/privacy/privacy-min-js?v=22"></script>
# <!-- 新天地用JS / 開始 -->
# <script src="/cathaylife/web/headerfooter/js/bodyScrollLock.js?v=22"></script>
# <script src="/cathaylife/web/headerfooter/js/headerfooter.js?v=22"></script>
# <!-- 新天地用JS / 結束 -->
# <!--簡易預約回首頁的商品頁URL-->
# <script>
# $(function () {
# var locationPath = "easy-reserve";
# var thisHref = $(location).attr('href');
# if(thisHref.indexOf(locationPath) == -1 ){
# sessionStorage['BackUrl']=thisHref ;
# }
# })
# </script>
# <!-- smartAlfa 202007 -->
# <div id="appendSmartAll"><div class="smart_all"> <div class="smart_inner"><div class="smart_say" id="hi" style="display: none;"> <div class="say"> <p><span style="color: #4AB234;font-weight: 400;">智能客服阿發</span> <br/>有任何問題隨時找我！				</p> </div> </div> <div class="smart_say" id="help" style="display:none"> <div class="say"> <p><span style="color: #4AB234;font-weight: 400;">智能客服阿發</span> <br/>Hi~需要幫忙嗎？				</p> </div> </div> <div class="smart_say" id="OneMinuteActive" style="display: none;"> <div class="say"> <p><span style="color: #4AB234;font-weight: 400;">智能客服阿發</span> <br/>Hi~需要幫忙嗎？				</p> </div> </div> <div class="smart_box"> <iframe class="smart_iframe" frameborder="0" src=""></iframe> </div> <div class="smart_icon"> <div class="smart_alpha"> </div> <div class="smart_up"> <img alt="" class="img-responsive" src="https://www.cathaylife.com.tw/website/eService/images/smart_top@2x.png"/> </div> </div> </div> </div></div>
# <script>
# var locationPath = '/contact-Index/Info/location';
#   if(location.href.indexOf(locationPath) > -1){
# 	var jsFile = document.createElement('script');
# 	jsFile.setAttribute('type', 'text/javascript');
# 	jsFile.setAttribute('src',  '/cathaylife/Web/headerfooter/js/smart.js');
# 	document.getElementsByTagName('body')[0].appendChild(jsFile);
#    }else{
# 	 var css = '<link href="https://www.cathaylife.com.tw/website/eService/css/smart_style.css" rel="stylesheet">';
#          $(css).appendTo('head');
# 	 var urlHiddenList = '/cathaylife/campaign';
# 	 if(location.href.indexOf(urlHiddenList) === -1) {
# 	        var jsFile = document.createElement('script');
# 	        jsFile.setAttribute('type', 'text/javascript');
# 		jsFile.setAttribute('src',  'https://www.cathaylife.com.tw/website/eService/js/iframe-alphaAppendHtml.js');
# 		document.getElementsByTagName('body')[0].appendChild(jsFile);
# 		$('.smart_box').css('display','block');
# 	 }
#   }
# </script><script src="https://www.cathaylife.com.tw/website/eService/js/iframe-alphaAppendHtml.js" type="text/javascript"></script>
# <!-- jQuery -->
# <!--mdrt_all-->
# <script src="https://www.cathaylife.com.tw/website/PFWeb/html/PF/W0/cathay_mdrt/js/consultant-sticker.js" type="text/javascript"></script><div class="__CathayLifeMajiConsultant extra_class" id="some_id" style="position: fixed; z-index: 105; right: 6px; bottom: 150px; transition: bottom 0.3s ease 0s; display: none;"><a href="https://campaigns.cathaylife.com.tw/OAWeb/html/OA/C8/index.html" style="width:86px;height:92px;display:block;cursor:pointer;background-position:0 0;background-image:url(data:image/png;base64,...)" target="_blank"></a></div>
# <!--mdrt_all end-->
# <script src="/cathaylife/web/js/custom/goaltrigger.js" type="text/javascript"></script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WLKJB7" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KCP5QFP" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!--Aixon tracking code(全站 retargeting 程式碼)-->
# <script>
# (function(){
# var dmp_id ="";
# try {
# dmp_id = ("; " + document.cookie).split("; cubcsapersisted=").pop().split(";").shift().substring(7).split("_")[0];
# }catch(err) {
# }
# if (typeof window.APPIER_RETARGET == 'undefined') {
# (function(w, d, s, m) {
# var f = d.getElementsByTagName('script')[0],
# j = d.createElement('script'),
# ns = 'APPIER_RETARGET';
# w._appierSendQueue = w._appierSendQueue || [];
# w['appierRetargetJson'] = { id: s, site: m};
# j.async = true;
# j.src = '//jscdn.appier.net/aa.js?id='+m;
# f.parentNode.insertBefore(j, f);
# !w[ns] && (w[ns] = {});
# (!w[ns].send) && (w[ns].send = function(j){
# w._appierSendQueue.push(j);
# });
# })(window, document, "Uj4k", "cathaylife.com.tw");
# }
# window.APPIER_RETARGET.send({"t": "pv_track", "action_id": "xzItEhm3hbEIh48", "track_id": "7I3ExxjGCzfUbbI", "isCountReload": true, "counter": 0});
# window.APPIER_RETARGET.send({"t": "pv_track", "action_id": "27EzS25j5bWvzbU", "track_id": "7I3ExxjGCzfUbbI", "isCountReload": false, "counter": 1});
# window.APPIER_RETARGET.send({'dmp_id': dmp_id});
# })();
# </script>
# <!--Aixon tracking code(全站 retargeting 程式碼)end-->
# </body></html>

# %%
containers = page_soup.findAll("h3" , {"class":"title-article-light"})
# print(containers)
print(len(containers))
