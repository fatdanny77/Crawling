# %%
# !pip -V
# Out:
# pip 19.0.3 from c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pip (python 3.7)

# %%
# !pip install requests
# Out:
# ...
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install beautifulsoup4
# Out:
# ...
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup

# %%
re = requests.get("https://www.ccclub.io/course/2019Spring")
print(re.status_code)
print(re.text)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="zh-Hant">
#
# <head>
# <title> ccClub  | Course List</title>
# <!-- Latest compiled and minified CSS -->
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
#
# <!-- Optional theme -->
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap-theme.min.css" integrity="sha384-rHyoN1iRsVXV4nD0JutlnGaslCJuC7uwjduW9SVrLvRYooPp2bWYgmgJQIXwl/Sp" crossorigin="anonymous">
#
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#
# <!-- google font -->
# <link href="https://fonts.googleapis.com/css?family=Pacifico|Courgette" rel="stylesheet">
#
#
# <link rel="stylesheet" href="https://ccclub-static.s3.amazonaws.com/static/css/mystyle.css">
#
# ...

# %%
soup = BeautifulSoup(re.text, "html.parser")
print(soup.title)
print(soup.title.string)
print(soup.title.text)
# Out:
# <title> ccClub  | Course List</title>
#  ccClub  | Course List
#  ccClub  | Course List

# %%
body = soup.tbody
for tr in body.find_all("tr"):
    td = tr.find_all("td")
    print(td[2].text)
# Out:
# 上課內容
# Introduction, Alumni experience sharing
# Data type, I/O, Escape character, If statement, String (HW1 announce)
# Object, List, Loop
# More about loops, Function
# Sorting, Recursion (HW1 due, HW2 announce)
# Dictionary, Error Handling
# File IO, Module (HW2 due, HW3 announce)
# Web Crawler
# Advanced Web Crawler
# Learning by doing - Project (HW3 due, HW4 announce)
# Learning by doing - Project
# Learning by doing - Project (HW4 due)
# Demo Party

# %%
re2 = requests.get("https://www.ptt.cc/bbs/NBA/index.html")
soup2 = BeautifulSoup(re2.text, "html.parser")
body2 = soup.body
for div in body.find_all("div"):
    for div in div:
        for div in div:
    td = tr.find_all("td")
    print(td[2].text)
# Out:
# 200
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# ...

# %%
import requests
from bs4 import BeautifulSoup

re2 = requests.get("https://www.ptt.cc/bbs/hotboards.html")
soup = BeautifulSoup(re2.text, "html.parser")

# %%
d = {}
q = {}
for element in soup.findAll("div" , {"class":"b-ent"}):
    board_name = element.find("div" , {"class":"board-name"}).text
    user_num = int(element.find("div" , {"class":"board-nuser"}).text)
    board_title = element.find("div" , {"class":"board-title"}).text
    d[board_name] = user_num
    q[board_title] = user_num

# %%
q
# Out:
# {'◎【八卦】沒四千萬別出門': 13549,
#  '◎[NBA] Lillard50分絕殺 李家之光!': 3877,
#  '◎[希洽] 人生還有其他路的  別爆雷': 3563,
#  '◎[棒球]中職三十 Baseball is Life': 3427,
#  '◎討論或請益 標題也可以加個〝雷〞': 3083,
#  '◎勿PO心情文 違者板規處分': 2242,
#  '◎[歐美影集] 凜冬將至': 1816,
#  '◎[政黑] 你確定要打這個！？': 1622,
#  '◎[韓星] 發/推文前請務必詳閱板規': 1296,
#  '◎[省錢] 2020板主大選': 1262,
#  '◎[西斯] 徵文主題 - 孑': 1255,
#  '◎問機文用範本 發文前請看板規': 1110,
#  '◎[LoL] 5/1-5/7 MSI Play-In': 1006,
#  '◎[汽車] 發文前請閱讀板規': 998,
#  '◎[媽寶] 群組文限定週四發表': 954,
#  '◎[科技] 凡事切記 獨立思考': 878,
#  '◎[男女] 置底請詳閱': 842,
#  '◎[女孩] Women與惡的距離': 837,
#  '◎虎航開賣OKA,SDJ,TYO,HKD,HNA,AKJ': 756,
#  '◎《表特板》板主徵選報名中': 739,
#  '◎[婚姻] 無法刪文、發文前三思': 705,
#  '◎[韓綜] Show Me The 新板主!': 696,
#  '◎[爐石] 冠軍 人中之龍 Hunterace': 648,
#  '◎[ＥＳ] 穿長裙寬褲騎車是很危險的': 619,
#  '◎[電蝦]全國最大客服? 送修請看RGB': 567,
#  '◎[就可] 板主選舉報名4/15~5/14': 559,
#  '◎[房屋] 徵選板主 (詳#1RMSkwWr)': 516,
#  '◎[PS4] 春天 別打了 又要骨折了': 505,
#  '◎[歐兔] 請詳讀板規及文摘^.^': 500,
#  '◎[高雄] 四草志工有興趣的見置底': 486,
#  '◎[神魔] 健檢文移板案  請積極投票': 481,
#  '◎[韓劇] 又開始啊啊啊': 476,
#  '◎[媽佛] 這裡不是漫威板': 476,
# ...
